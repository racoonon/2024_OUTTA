# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

GOOGLE_API_KEY= 'AIzaSyDBYOYA-qBeBpjCKPclDQpjYzoVVSm1q_Y'

genai.configure(api_key=GOOGLE_API_KEY)
# GeminiAPI는 무료, GPTAPI는 유료

# %% [markdown]
# # How to use

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Tell me about Newton's second law.")
print(response.text)
# prompt engineering 수행
# Out:
# **Newton's Second Law of Motion**
#
# Isaac Newton's second law of motion, also known as the law of acceleration, explains the relationship between an object's mass, acceleration, and the forces acting on it.
#
# **Statement:**
#
# >The acceleration of an object is directly proportional to the net force acting on it, and inversely proportional to its mass.
#
# **Mathematical Form:**
#
# ```
# F = ma
# ```
#
# where:
#
# * **F** is the net force acting on the object (in Newtons, N)
# * **m** is the mass of the object (in kilograms, kg)
# * **a** is the acceleration of the object (in meters per second squared, m/s²)
#
# **Interpretation:**
#
# * **Direct Proportionality:** The greater the net force applied to an object, the greater its acceleration will be.
# * **Inverse Proportionality:** The greater the mass of an object, the smaller its acceleration will be for a given force.
#
# **Implications:**
#
# * **Force and Acceleration:** Newton's second law shows that force is not the same as acceleration. Force is the cause of acceleration, not acceleration itself.
# * **Mass and Inertia:** An object's mass is a measure of its inertia, which is its resistance to changes in motion. The more massive an object, the harder it is to accelerate.
# * **Balanced Forces:** If the net force acting on an object is zero, the object will not accelerate.
#
# **Examples:**
#
# * A car accelerates when the driver presses down on the gas pedal, increasing the force applied by the engine.
# * A falling object accelerates because of the force of gravity, pulling it towards the earth's center.
# * A person standing still has zero net force acting on them, so their acceleration is also zero.

# %% [markdown]
# # 역할 부여하기

# %%
model = genai.GenerativeModel('gemini-pro')
instruction = "You are an elementary school physics teacher."
prompt = "Tell me about Newton's second law."

# %%
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# 설명이 엄청 쉬워짐
# Out:
# **Newton's Second Law of Motion**
#
# Newton's second law describes how objects in motion respond to forces acting on them. It states that:
#
# **The acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass.**
#
# In equation form:
#
# ```
# F = ma
# ```
#
# where:
#
# * F is the net force acting on the object (in newtons)
# * m is the mass of the object (in kilograms)
# * a is the acceleration of the object (in meters per second squared)
#
# **Example Problems:**
#
# **1. A 10 kg object is pushed with a force of 20 N. What is its acceleration?**
#
# ```
# F = 20 N
# m = 10 kg
# a = ?
# ```
#
# Using Newton's second law:
#
# ```
# 20 N = 10 kg * a
# a = 2 m/s²
# ```
#
# Therefore, the object accelerates at a rate of 2 meters per second squared.
#
# **2. A car with a mass of 1200 kg is traveling at a velocity of 20 m/s. The driver applies the brakes, which exert a force of -4000 N for 10 seconds. What is the car's final velocity?**
#
# ```
# F = -4000 N (negative because it opposes motion)
# m = 1200 kg
# t = 10 s
# v_i = 20 m/s
# v_f = ?
# ```
#
# First, calculate the acceleration using Newton's second law:
#
# ```
# -4000 N = 1200 kg * a
# a = -3.33 m/s² (negative because it slows down the car)
# ```
#
# Then, use the equation of motion:
#
# ```
# v_f = v_i + a * t
# v_f = 20 m/s + (-3.33 m/s²) * 10 s
# v_f = 6.67 m/s
# ```
#
# Therefore, the car's final velocity after braking is 6.67 meters per second.

# %% [markdown]
# # Instruction 추가하기

# %%
instruction = "You must explain the concept with example problems."
prompt = "Tell me about Newton's second law."

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# **Newton's Second Law of Motion**
#
# Newton's second law describes how objects in motion respond to forces acting on them. It states that:
#
# **The acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass.**
#
# In equation form:
#
# ```
# F = ma
# ```
#
# where:
#
# * F is the net force acting on the object (in newtons)
# * m is the mass of the object (in kilograms)
# * a is the acceleration of the object (in meters per second squared)
#
# **Example Problems:**
#
# **1. A 10 kg object is pushed with a force of 20 N. What is its acceleration?**
#
# ```
# F = 20 N
# m = 10 kg
# a = ?
# ```
#
# Using Newton's second law:
#
# ```
# 20 N = 10 kg * a
# a = 2 m/s²
# ```
#
# Therefore, the object accelerates at a rate of 2 meters per second squared.
#
# **2. A car with a mass of 1200 kg is traveling at a velocity of 20 m/s. The driver applies the brakes, which exert a force of -4000 N for 10 seconds. What is the car's final velocity?**
#
# ```
# F = -4000 N (negative because it opposes motion)
# m = 1200 kg
# t = 10 s
# v_i = 20 m/s
# v_f = ?
# ```
#
# First, calculate the acceleration using Newton's second law:
#
# ```
# -4000 N = 1200 kg * a
# a = -3.33 m/s² (negative because it slows down the car)
# ```
#
# Then, use the equation of motion:
#
# ```
# v_f = v_i + a * t
# v_f = 20 m/s + (-3.33 m/s²) * 10 s
# v_f = 6.67 m/s
# ```
#
# Therefore, the car's final velocity after braking is 6.67 meters per second.

# %% [markdown]
# # 할루시네이션

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Use the four basic operations (+, -, /, *) to appropriately operate 4, 9, 10, 13 to make 24.")
print(response.text)
# 오답을 정답처럼 출력함
# Out:
# (10 * 9) / (13 - 4) = 24

# %% [markdown]
# # Few shot Prompting
#
# 예시 case를 입력에 같이 넣어주면 할루시네이션 문제 어느정도는 해결 가능함

# %%
prompt = """
The movie was good // positive
The movie was quite bad // negative
I really like the movie, but the ending was lacking // neutral
I loved the movie //
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# positive

# %% [markdown]
# # 추론 task에서는 소용이 없다...
# LLM은 추론에 약함

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Is that True? : The odd numbers in 15, 32, 5, 13, 82, 7, 1 add up to an even number.")
print(response.text)
# Out:
# False

# %%
model = genai.GenerativeModel('gemini-pro')
#프롬프트
prompt = """
The odd numbers in this group add up to an even number: 4, 8, 9, 15, 12, 2, 1.
A: The answer is False.
The odd numbers in this group add up to an even number: 17,  10, 19, 4, 8, 12, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 16,  11, 14, 4, 8, 13, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 17,  9, 10, 12, 13, 4, 2.
A: The answer is False.
The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1.
A:
"""
# 모델 호출
response = model.generate_content(prompt)
print(response.text)
# Out:
# The answer is False.

# %% [markdown]
# # Chain of Thought

# %%
instruction = "Let's think step by step. Explain about your thought."
prompt = """
The odd numbers in this group add up to an even number: 4, 8, 9, 15, 12, 2, 1.
A: The answer is False.
The odd numbers in this group add up to an even number: 17,  10, 19, 4, 8, 12, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 16,  11, 14, 4, 8, 13, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 17,  9, 10, 12, 13, 4, 2.
A: The answer is False.
The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1.
A:
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# The answer is True.

# %% [markdown]
# # **과제** :
#
# 아래 문제에서는 할루시네이션이 발생한다. (답은 10 apples가 나와야 한다.)

# %%
prompt = """
I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman.
I then went and bought 5 more apples and ate 1. How many apples did I remain with?
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# 12 apples

# %% [markdown]
# ***할루시네이션이 발생한 위의 문제를 올바르게 풀게끔 프롬프트를 만들어보세요.***

# %%
instruction = "Let's think step by step. Explain about your thought."
prompt = """
I went to the market and bought 20 apples. I gave 4 apples to the neighbor and 2 to the repairman.
I then went and bought 6 more apples and ate 2. How many apples did I remain with?
A: The answer is 18.
I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman.
I then went and bought 5 more apples and ate 1. How many apples did I remain with?
A:
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# **Step 1: Understand the information given.**
#
# I bought 10 apples.
# I gave 2 apples to the neighbor.
# I gave 2 apples to the repairman.
# I bought 5 more apples.
# I ate 1 apple.
#
# **Step 2: Determine the number of apples I had after distributing.**
#
# 10 - 2 - 2 = 6
#
# I had 6 apples left after distributing.
#
# **Step 3: Add the apples I bought.**
#
# 6 + 5 = 11
#
# I had 11 apples after buying 5 more.
#
# **Step 4: Subtract the apples I ate.**
#
# 11 - 1 = 10
#
# **Therefore, I remained with 10 apples.**
